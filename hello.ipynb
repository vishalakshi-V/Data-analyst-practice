# %%
name=input("Enter your name:")
print("Hello",name)

a=int(input("Enter number:"))
b=int(input("Enter number:"))
print("Sum:",a+b)
# Out:
# Enter your name: vishala
# Hello vishala
# Enter number: 123
# Enter number: 451
# Sum: 574
